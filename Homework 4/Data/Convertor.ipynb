# %%
import pandas as pd

# Load the XPT file
df = pd.read_sas('LLCP2022.xpt', format='xport')

# Save it as a CSV file
df.to_csv('LLCP2022.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Load the XPT file
# ----> 4 df = pd.read_sas('LLCP2022.xpt', format='xport')
#       6 # Save it as a CSV file
#       7 df.to_csv('LLCP2022.csv', index=False)
#
# File c:\Users\rcc_0\anaconda3\Lib\site-packages\pandas\io\sas\sasreader.py:178, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     175     return reader
#     177 with reader:
# --> 178     return reader.read()
#
# File c:\Users\rcc_0\anaconda3\Lib\site-packages\pandas\io\sas\sas_xport.py:480, in XportReader.read(self, nrows)
#     478     self.close()
#     479     raise StopIteration
# --> 480 raw = self.filepath_or_buffer.read(read_len)
#     481 data = np.frombuffer(raw, dtype=self._dtype, count=read_lines)
#     483 df_data = {}
#
# MemoryError:
